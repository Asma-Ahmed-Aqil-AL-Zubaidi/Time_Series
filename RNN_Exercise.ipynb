# %% [markdown]
# <a href="https://colab.research.google.com/github/Asma-Ahmed-Aqil-AL-Zubaidi/Time_Series/blob/main/RNN_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **RNN Introduction**

# %% [markdown]
# ## Importing required libraries

# %% [markdown]
# ## Loading and preprocessing the data
# ### Dataset 4-Deep learning/5-Time Series Forecasting (RNN)/LAB/ٌDatasets/traffic.csv

# %% [markdown]
# ## Visualization

# %% [markdown]
# ## Split the data into train and test

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Visualization of results
